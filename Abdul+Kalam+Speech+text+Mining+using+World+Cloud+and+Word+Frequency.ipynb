# %%
pwd()
# Out:
# 'C:\\Users\\User'

# %%
import os

with open(os.getcwd()+ "/Abdul_Kalam_Speech.txt", 'r') as fh:  
    filedata = fh.read()

# %%
#Print first 500 characters in the file
print("Data read from file : ", filedata[0:500] )
# Out:
# Data read from file :  I am delighted to be here at the Indian Institute of Technology Madras and address the members of this renowned place of learning and other guests present here. My greetings to you all.
#
# Friends, before I begin my address I want to share a thought with all the youth present here. I have met, so far, 11 million youth like you in a decade?s time, in India and abroad. I have seen their hopes, experienced their pains, walked with their aspirations and heard through their despair. All this experience

# %% [markdown]
# # Import Data Using Nltk Library

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus.reader.plaintext import PlaintextCorpusReader

# %%
corpus=PlaintextCorpusReader(os.getcwd(),"Abdul_Kalam_Speech.txt")
print(corpus)
# Out:
# <PlaintextCorpusReader in 'C:\\Users\\User'>

# %% [markdown]
# # Exploring the Corpus

# %%
print("Files in this corpus : ", corpus.fileids())
# Out:
# Files in this corpus :  ['Abdul_Kalam_Speech.txt']

# %%
paragraphs=corpus.paras()
print("\n Total paragraphs in this corpus : ", len(paragraphs))
# Out:
#  Total paragraphs in this corpus :  5

# %%
sentences=corpus.sents()
print("\n Total sentences in this corpus : ", len(sentences))
print("\n The first sentence : ", sentences[0])
# Out:
#  Total sentences in this corpus :  32
#
#  The first sentence :  ['I', 'am', 'delighted', 'to', 'be', 'here', 'at', 'the', 'Indian', 'Institute', 'of', 'Technology', 'Madras', 'and', 'address', 'the', 'members', 'of', 'this', 'renowned', 'place', 'of', 'learning', 'and', 'other', 'guests', 'present', 'here', '.']

# %%
#Extract words from the corpus
print("\n Words in this corpus : ",corpus.words() )
# Out:
#  Words in this corpus :  ['I', 'am', 'delighted', 'to', 'be', 'here', 'at', ...]

# %%
#Find the frequency distribution of words in the corpus
course_freq_dist=nltk.FreqDist(corpus.words())

#Print most commonly used words
print("Top 10 words in the corpus : ", course_freq_dist.most_common(10))

#find the distribution for a specific word
print("\n Distribution for \"delighted\" : ",course_freq_dist.get("delighted"))
# Out:
# Top 10 words in the corpus :  [(',', 42), ('the', 29), ('of', 25), ('.', 23), ('to', 22), ('and', 14), ('in', 12), ('is', 12), ('I', 10), ('a', 10)]
#
#  Distribution for "delighted" :  1

# %% [markdown]
# # Tokenization
#
# Tokenization refers to converting a text string into individual tokens. Tokens may be words or punctations

# %%
token_list = nltk.word_tokenize(filedata)
print("Token List : ",token_list[:20])
print("\n Total Tokens : ",len(token_list))
# Out:
# Token List :  ['I', 'am', 'delighted', 'to', 'be', 'here', 'at', 'the', 'Indian', 'Institute', 'of', 'Technology', 'Madras', 'and', 'address', 'the', 'members', 'of', 'this', 'renowned']
#
#  Total Tokens :  683

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
wordcloud = WordCloud().generate(filedata)

# %%
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
def wordfreq(tokens):
    word_freq = {}
    for tok in token_list:
        if tok.lower() in word_freq:
            word_freq = tok.lower.append()
        else:
            word_freq = tok.lower()
    return word_freq

# %%
import nltk
import operator
# %matplotlib inline
Freq_dist_nltk=nltk.FreqDist(token_list)
print(Freq_dist_nltk)
sorted_d = sorted(Freq_dist_nltk.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_d[:25])
Freq_dist_nltk.plot(25, cumulative=False)
# Out:
# <FreqDist with 327 samples and 683 outcomes>
# [(',', 42), ('the', 29), ('of', 25), ('.', 25), ('to', 22), ('and', 14), ('in', 12), ('is', 12), ('I', 10), ('a', 10), ('their', 10), ('you', 8), ('with', 6), ('life', 6), ('my', 5), ('?', 5), ('they', 5), ('at', 4), ('this', 4), ('all', 4), ('have', 4), ('like', 4), ('India', 4), ('me', 4), ('which', 4)]

# %% [markdown]
# # Cleansing Text

# %% [markdown]
# ### Remove Punctuation

# %%
#Use the Punkt library to extract tokens
token_list2 = list(filter(lambda token: nltk.tokenize.punkt.PunktToken(token).is_non_punct, token_list))
print("Token List after removing punctuation : ",token_list2[:20])
print("\nTotal tokens after removing punctuation : ", len(token_list2))
# Out:
# Token List after removing punctuation :  ['I', 'am', 'delighted', 'to', 'be', 'here', 'at', 'the', 'Indian', 'Institute', 'of', 'Technology', 'Madras', 'and', 'address', 'the', 'members', 'of', 'this', 'renowned']
#
# Total tokens after removing punctuation :  599

# %%
def comment(tokens):
    comment_words = ' '
    for word in tokens:
        comment_words = comment_words + word + ' '
    return comment_words

# %%
cleaned_text = comment(token_list2)

# %%
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(cleaned_text)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# ### Normalization

# %%
token_list3=[word.lower() for word in token_list2 ]
print("Token list after converting to lower case : ", token_list3[:20])
print("\nTotal tokens after converting to lower case : ", len(token_list3))
# Out:
# Token list after converting to lower case :  ['i', 'am', 'delighted', 'to', 'be', 'here', 'at', 'the', 'indian', 'institute', 'of', 'technology', 'madras', 'and', 'address', 'the', 'members', 'of', 'this', 'renowned']
#
# Total tokens after converting to lower case :  599

# %%
Freq_dist_nltk=nltk.FreqDist(token_list3)
print(Freq_dist_nltk)
sorted_d = sorted(Freq_dist_nltk.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_d[:25])
Freq_dist_nltk.plot(25, cumulative=False)
# Out:
# <FreqDist with 295 samples and 599 outcomes>
# [('the', 31), ('of', 25), ('to', 23), ('and', 14), ('in', 13), ('is', 12), ('you', 11), ('i', 10), ('a', 10), ('their', 10), ('they', 8), ('at', 6), ('my', 6), ('with', 6), ('life', 6), ('all', 5), ('that', 5), ('excellence', 5), ('this', 4), ('have', 4), ('like', 4), ('india', 4), ('me', 4), ('which', 4), ('unique', 4)]

# %%
#Word Cloud Function calling
Normalized_text = comment(token_list3)

# %%
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(Normalized_text)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# # Stop Word Removal

# %%
#Download the standard stopword list
nltk.download('stopwords')
from nltk.corpus import stopwords

#Remove stopwords
token_list4 = list(filter(lambda token: token not in stopwords.words('english'), token_list3))
print("Token list after removing stop words : ", token_list4[:20])
print("\nTotal tokens after removing stop words : ", len(token_list4))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Token list after removing stop words :  ['delighted', 'indian', 'institute', 'technology', 'madras', 'address', 'members', 'renowned', 'place', 'learning', 'guests', 'present', 'greetings', 'friends', 'begin', 'address', 'want', 'share', 'thought', 'youth']
#
# Total tokens after removing stop words :  298

# %%
#Frequncy Distribution after stop word removal
Freq_dist_nltk=nltk.FreqDist(token_list4)
print(Freq_dist_nltk)
sorted_d = sorted(Freq_dist_nltk.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_d[:25])
Freq_dist_nltk.plot(25, cumulative=False)
# Out:
# <FreqDist with 225 samples and 298 outcomes>
# [('life', 6), ('excellence', 5), ('like', 4), ('india', 4), ('unique', 4), ('independence', 4), ('students', 4), ('place', 3), ('friends', 3), ('share', 3), ('youth', 3), ('time', 3), ('would', 3), ('everybody', 3), ('else', 3), ('let', 3), ('process', 3), ('dreams', 3), ('mahatma', 3), ('indian', 2), ('madras', 2), ('address', 2), ('present', 2), ('million', 2), ('experience', 2)]

# %%
#Word Cloud Function calling
Stop_word = comment(token_list4)

# %%
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(Stop_word)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# # Stemming

# %%
#Use the PorterStemmer library for stemming.
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

#Stem data
token_list5 = [stemmer.stem(word) for word in token_list4 ]
print("Token list after stemming : ", token_list5[:20])
print("\nTotal tokens after Stemming : ", len(token_list5))
# Out:
# Token list after stemming :  ['delight', 'indian', 'institut', 'technolog', 'madra', 'address', 'member', 'renown', 'place', 'learn', 'guest', 'present', 'greet', 'friend', 'begin', 'address', 'want', 'share', 'thought', 'youth']
#
# Total tokens after Stemming :  298

# %%
#Frequncy Distribution after stop word removal
Freq_dist_nltk=nltk.FreqDist(token_list5)
print(Freq_dist_nltk)
sorted_d = sorted(Freq_dist_nltk.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_d[:25])
Freq_dist_nltk.plot(25, cumulative=False)
# Out:
# <FreqDist with 215 samples and 298 outcomes>
# [('life', 6), ('excel', 5), ('like', 4), ('time', 4), ('india', 4), ('uniqu', 4), ('dream', 4), ('independ', 4), ('student', 4), ('indian', 3), ('place', 3), ('learn', 3), ('friend', 3), ('share', 3), ('youth', 3), ('experi', 3), ('would', 3), ('everybodi', 3), ('els', 3), ('fight', 3), ('let', 3), ('process', 3), ('work', 3), ('mahatma', 3), ('madra', 2)]

# %%
Stemmed_text = comment(token_list5)

# %%
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(Stemmed_text)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# # Lemmatization

# %%
#Use the wordnet library to map words to their lemmatized form
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
token_list6 = [lemmatizer.lemmatize(word) for word in token_list4 ]
print("Token list after Lemmatization : ", token_list6[:20])
print("\nTotal tokens after Lemmatization : ", len(token_list6))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Token list after Lemmatization :  ['delighted', 'indian', 'institute', 'technology', 'madras', 'address', 'member', 'renowned', 'place', 'learning', 'guest', 'present', 'greeting', 'friend', 'begin', 'address', 'want', 'share', 'thought', 'youth']
#
# Total tokens after Lemmatization :  298

# %%
#Frequncy Distribution after stop word removal
Freq_dist_nltk=nltk.FreqDist(token_list6)
print(Freq_dist_nltk)
sorted_d = sorted(Freq_dist_nltk.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_d[:25])
Freq_dist_nltk.plot(25, cumulative=False)
# Out:
# <FreqDist with 220 samples and 298 outcomes>
# [('life', 6), ('excellence', 5), ('like', 4), ('time', 4), ('india', 4), ('unique', 4), ('dream', 4), ('independence', 4), ('student', 4), ('indian', 3), ('place', 3), ('friend', 3), ('share', 3), ('youth', 3), ('experience', 3), ('would', 3), ('everybody', 3), ('else', 3), ('let', 3), ('process', 3), ('mahatma', 3), ('madras', 2), ('address', 2), ('present', 2), ('want', 2)]

# %%
Lemmatized_text = comment(token_list6)

# %%
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(Lemmatized_text)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# # Analysis of Speech

# %% [raw]
# The Speech more talks about the positiveness. The most used words such as life,excellence,dream,unique,share etc and all these
# words tells that the speech is about dream big to excell in life.

# %% [markdown]
# # Text Processing

# %%
Machine_Learning = '''Machine Learning is the field of study that gives computers 
the capability to learn without being explicitly programmed. ML is one of the most exciting 
technologies that one would have ever come across. As it is evident from the name, it gives the 
computer that which makes it more similar to humans: 
The ability to learn. Machine learning is actively being used today, 
perhaps in many more places than one would expect.'''

# %%
#Tokenizing
Tokens = Machine_Learning.split()

# %%
print(Tokens)
# Out:
# ['Machine', 'Learning', 'is', 'the', 'field', 'of', 'study', 'that', 'gives', 'computers', 'the', 'capability', 'to', 'learn', 'without', 'being', 'explicitly', 'programmed.', 'ML', 'is', 'one', 'of', 'the', 'most', 'exciting', 'technologies', 'that', 'one', 'would', 'have', 'ever', 'come', 'across.', 'As', 'it', 'is', 'evident', 'from', 'the', 'name,', 'it', 'gives', 'the', 'computer', 'that', 'which', 'makes', 'it', 'more', 'similar', 'to', 'humans:', 'The', 'ability', 'to', 'learn.', 'Machine', 'learning', 'is', 'actively', 'being', 'used', 'today,', 'perhaps', 'in', 'many', 'more', 'places', 'than', 'one', 'would', 'expect.']

# %%
#Frequncy Distribution after stop word removal
Freq_dist_nltk=nltk.FreqDist(Tokens)
print(Freq_dist_nltk)
sorted_d = sorted(Freq_dist_nltk.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_d[:25])
Freq_dist_nltk.plot(25, cumulative=False)
# Out:
# <FreqDist with 51 samples and 72 outcomes>
# [('the', 5), ('is', 4), ('that', 3), ('to', 3), ('one', 3), ('it', 3), ('Machine', 2), ('of', 2), ('gives', 2), ('being', 2), ('would', 2), ('more', 2), ('Learning', 1), ('field', 1), ('study', 1), ('computers', 1), ('capability', 1), ('learn', 1), ('without', 1), ('explicitly', 1), ('programmed.', 1), ('ML', 1), ('most', 1), ('exciting', 1), ('technologies', 1)]

# %%
words = comment(Tokens)

# %%
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(words)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
#identify the stop word manually from the sentence
stop_word = ['is','the','of','that','to','would','have','As','it','from','which','in','than','As']
print(stop_word)
# Out:
# ['is', 'the', 'of', 'that', 'to', 'would', 'have', 'As', 'it', 'from', 'which', 'in', 'than', 'As']

# %%
text_cleaned = []
for word in Tokens:
    if word.lower() in stop_word:
        pass
    else:
        text_cleaned.append(word)
print(text_cleaned)
# Out:
# ['Machine', 'Learning', 'field', 'study', 'gives', 'computers', 'capability', 'learn', 'without', 'being', 'explicitly', 'programmed.', 'ML', 'one', 'most', 'exciting', 'technologies', 'one', 'ever', 'come', 'across.', 'As', 'evident', 'name,', 'gives', 'computer', 'makes', 'more', 'similar', 'humans:', 'ability', 'learn.', 'Machine', 'learning', 'actively', 'being', 'used', 'today,', 'perhaps', 'many', 'more', 'places', 'one', 'expect.']

# %%
Freq_dist_nltk=nltk.FreqDist(text_cleaned)
print(Freq_dist_nltk)
sorted_d = sorted(Freq_dist_nltk.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_d[:25])
Freq_dist_nltk.plot(25, cumulative=False)
# Out:
# <FreqDist with 38 samples and 44 outcomes>
# [('one', 3), ('Machine', 2), ('gives', 2), ('being', 2), ('more', 2), ('Learning', 1), ('field', 1), ('study', 1), ('computers', 1), ('capability', 1), ('learn', 1), ('without', 1), ('explicitly', 1), ('programmed.', 1), ('ML', 1), ('most', 1), ('exciting', 1), ('technologies', 1), ('ever', 1), ('come', 1), ('across.', 1), ('As', 1), ('evident', 1), ('name,', 1), ('computer', 1)]

# %%
words = comment(text_cleaned)

# %%
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(words)

# %%
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
